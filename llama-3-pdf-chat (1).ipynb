# %%
import os
import pandas as pd

# %%
#langchain==0.0.300

# %%
# !pip install transformers==4.33.0 accelerate==0.22.0 einops==0.6.1 langchain==0.1.17 xformers==0.0.21 bitsandbytes==0.41.1 sentence_transformers==2.2.2 chromadb==0.4.12 llama-index==0.10.36 llama-parse==0.4.2
# Out:
# Requirement already satisfied: transformers==4.33.0 in /opt/conda/lib/python3.10/site-packages (4.33.0)
# Requirement already satisfied: accelerate==0.22.0 in /opt/conda/lib/python3.10/site-packages (0.22.0)
# Requirement already satisfied: einops==0.6.1 in /opt/conda/lib/python3.10/site-packages (0.6.1)
# Requirement already satisfied: langchain==0.1.17 in /opt/conda/lib/python3.10/site-packages (0.1.17)
# Requirement already satisfied: xformers==0.0.21 in /opt/conda/lib/python3.10/site-packages (0.0.21)
# Requirement already satisfied: bitsandbytes==0.41.1 in /opt/conda/lib/python3.10/site-packages (0.41.1)
# Requirement already satisfied: sentence_transformers==2.2.2 in /opt/conda/lib/python3.10/site-packages (2.2.2)
# Requirement already satisfied: chromadb==0.4.12 in /opt/conda/lib/python3.10/site-packages (0.4.12)
# Requirement already satisfied: llama-index==0.10.36 in /opt/conda/lib/python3.10/site-packages (0.10.36)
# Requirement already satisfied: llama-parse==0.4.2 in /opt/conda/lib/python3.10/site-packages (0.4.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from transformers==4.33.0) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.15.1 in /opt/conda/lib/python3.10/site-packages (from transformers==4.33.0) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from transformers==4.33.0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from transformers==4.33.0) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from transformers==4.33.0) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers==4.33.0) (2023.12.25)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from transformers==4.33.0) (2.31.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers==4.33.0)
#   Using cached tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: safetensors>=0.3.1 in /opt/conda/lib/python3.10/site-packages (from transformers==4.33.0) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.10/site-packages (from transformers==4.33.0) (4.66.1)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from accelerate==0.22.0) (5.9.3)
# Requirement already satisfied: torch>=1.10.0 in /opt/conda/lib/python3.10/site-packages (from accelerate==0.22.0) (2.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /opt/conda/lib/python3.10/site-packages (from langchain==0.1.17) (2.0.25)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /opt/conda/lib/python3.10/site-packages (from langchain==0.1.17) (3.9.1)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /opt/conda/lib/python3.10/site-packages (from langchain==0.1.17) (4.0.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /opt/conda/lib/python3.10/site-packages (from langchain==0.1.17) (0.5.14)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /opt/conda/lib/python3.10/site-packages (from langchain==0.1.17) (1.33)
# Requirement already satisfied: langchain-community<0.1,>=0.0.36 in /opt/conda/lib/python3.10/site-packages (from langchain==0.1.17) (0.0.38)
# Requirement already satisfied: langchain-core<0.2.0,>=0.1.48 in /opt/conda/lib/python3.10/site-packages (from langchain==0.1.17) (0.1.52)
# Requirement already satisfied: langchain-text-splitters<0.1,>=0.0.1 in /opt/conda/lib/python3.10/site-packages (from langchain==0.1.17) (0.0.1)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /opt/conda/lib/python3.10/site-packages (from langchain==0.1.17) (0.1.56)
# Requirement already satisfied: pydantic<3,>=1 in /opt/conda/lib/python3.10/site-packages (from langchain==0.1.17) (1.10.15)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /opt/conda/lib/python3.10/site-packages (from langchain==0.1.17) (8.2.3)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.10/site-packages (from sentence_transformers==2.2.2) (0.16.2)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from sentence_transformers==2.2.2) (1.2.2)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from sentence_transformers==2.2.2) (1.11.4)
# Requirement already satisfied: nltk in /opt/conda/lib/python3.10/site-packages (from sentence_transformers==2.2.2) (3.8.1)
# Requirement already satisfied: sentencepiece in /opt/conda/lib/python3.10/site-packages (from sentence_transformers==2.2.2) (0.2.0)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in /opt/conda/lib/python3.10/site-packages (from chromadb==0.4.12) (0.7.3)
# Requirement already satisfied: fastapi<0.100.0,>=0.95.2 in /opt/conda/lib/python3.10/site-packages (from chromadb==0.4.12) (0.99.1)
# Requirement already satisfied: uvicorn>=0.18.3 in /opt/conda/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.4.12) (0.23.2)
# Requirement already satisfied: posthog>=2.4.0 in /opt/conda/lib/python3.10/site-packages (from chromadb==0.4.12) (3.5.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/conda/lib/python3.10/site-packages (from chromadb==0.4.12) (4.9.0)
# Requirement already satisfied: pulsar-client>=3.1.0 in /opt/conda/lib/python3.10/site-packages (from chromadb==0.4.12) (3.5.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /opt/conda/lib/python3.10/site-packages (from chromadb==0.4.12) (1.17.3)
# Requirement already satisfied: pypika>=0.48.9 in /opt/conda/lib/python3.10/site-packages (from chromadb==0.4.12) (0.48.9)
# Requirement already satisfied: overrides>=7.3.1 in /opt/conda/lib/python3.10/site-packages (from chromadb==0.4.12) (7.4.0)
# Requirement already satisfied: importlib-resources in /opt/conda/lib/python3.10/site-packages (from chromadb==0.4.12) (6.1.1)
# Requirement already satisfied: bcrypt>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from chromadb==0.4.12) (4.1.3)
# Requirement already satisfied: typer>=0.9.0 in /opt/conda/lib/python3.10/site-packages (from chromadb==0.4.12) (0.9.0)
# Requirement already satisfied: llama-index-agent-openai<0.3.0,>=0.1.4 in /opt/conda/lib/python3.10/site-packages (from llama-index==0.10.36) (0.2.4)
# Requirement already satisfied: llama-index-cli<0.2.0,>=0.1.2 in /opt/conda/lib/python3.10/site-packages (from llama-index==0.10.36) (0.1.12)
# Requirement already satisfied: llama-index-core<0.11.0,>=0.10.35 in /opt/conda/lib/python3.10/site-packages (from llama-index==0.10.36) (0.10.36)
# Requirement already satisfied: llama-index-embeddings-openai<0.2.0,>=0.1.5 in /opt/conda/lib/python3.10/site-packages (from llama-index==0.10.36) (0.1.9)
# Requirement already satisfied: llama-index-indices-managed-llama-cloud<0.2.0,>=0.1.2 in /opt/conda/lib/python3.10/site-packages (from llama-index==0.10.36) (0.1.6)
# Requirement already satisfied: llama-index-legacy<0.10.0,>=0.9.48 in /opt/conda/lib/python3.10/site-packages (from llama-index==0.10.36) (0.9.48)
# Requirement already satisfied: llama-index-llms-openai<0.2.0,>=0.1.13 in /opt/conda/lib/python3.10/site-packages (from llama-index==0.10.36) (0.1.18)
# Requirement already satisfied: llama-index-multi-modal-llms-openai<0.2.0,>=0.1.3 in /opt/conda/lib/python3.10/site-packages (from llama-index==0.10.36) (0.1.5)
# Requirement already satisfied: llama-index-program-openai<0.2.0,>=0.1.3 in /opt/conda/lib/python3.10/site-packages (from llama-index==0.10.36) (0.1.6)
# Requirement already satisfied: llama-index-question-gen-openai<0.2.0,>=0.1.2 in /opt/conda/lib/python3.10/site-packages (from llama-index==0.10.36) (0.1.3)
# Requirement already satisfied: llama-index-readers-file<0.2.0,>=0.1.4 in /opt/conda/lib/python3.10/site-packages (from llama-index==0.10.36) (0.1.22)
# Requirement already satisfied: llama-index-readers-llama-parse<0.2.0,>=0.1.2 in /opt/conda/lib/python3.10/site-packages (from llama-index==0.10.36) (0.1.4)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==0.22.0) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==0.22.0) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==0.22.0) (3.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==0.22.0) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==0.22.0) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==0.22.0) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==0.22.0) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==0.22.0) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==0.22.0) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==0.22.0) (10.2.10.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==0.22.0) (11.4.0.1)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==0.22.0) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==0.22.0) (2.14.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==0.22.0) (11.7.91)
# Requirement already satisfied: triton==2.0.0 in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==0.22.0) (2.0.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.10.0->accelerate==0.22.0) (69.0.3)
# Requirement already satisfied: wheel in /opt/conda/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.10.0->accelerate==0.22.0) (0.42.0)
# Requirement already satisfied: cmake in /opt/conda/lib/python3.10/site-packages (from triton==2.0.0->torch>=1.10.0->accelerate==0.22.0) (3.29.2)
# Requirement already satisfied: lit in /opt/conda/lib/python3.10/site-packages (from triton==2.0.0->torch>=1.10.0->accelerate==0.22.0) (18.1.4)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.17) (23.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.17) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.17) (1.9.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.17) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.17) (1.3.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/conda/lib/python3.10/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain==0.1.17) (3.21.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain==0.1.17) (0.9.0)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in /opt/conda/lib/python3.10/site-packages (from fastapi<0.100.0,>=0.95.2->chromadb==0.4.12) (0.27.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.15.1->transformers==4.33.0) (2024.2.0)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/conda/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain==0.1.17) (2.4)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /opt/conda/lib/python3.10/site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.1.17) (3.10.3)
# Requirement already satisfied: openai>=1.14.0 in /opt/conda/lib/python3.10/site-packages (from llama-index-agent-openai<0.3.0,>=0.1.4->llama-index==0.10.36) (1.28.0)
# Requirement already satisfied: deprecated>=1.2.9.3 in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index==0.10.36) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index==0.10.36) (1.0.8)
# Requirement already satisfied: httpx in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index==0.10.36) (0.27.0)
# Requirement already satisfied: llamaindex-py-client<0.2.0,>=0.1.18 in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index==0.10.36) (0.1.19)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index==0.10.36) (1.5.8)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index==0.10.36) (2.1.4)
# Requirement already satisfied: pillow>=9.0.0 in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index==0.10.36) (9.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index==0.10.36) (0.6.0)
# Requirement already satisfied: wrapt in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index==0.10.36) (1.14.1)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in /opt/conda/lib/python3.10/site-packages (from llama-index-readers-file<0.2.0,>=0.1.4->llama-index==0.10.36) (4.12.3)
# Requirement already satisfied: pypdf<5.0.0,>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from llama-index-readers-file<0.2.0,>=0.1.4->llama-index==0.10.36) (4.2.0)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in /opt/conda/lib/python3.10/site-packages (from llama-index-readers-file<0.2.0,>=0.1.4->llama-index==0.10.36) (0.0.26)
# Requirement already satisfied: click in /opt/conda/lib/python3.10/site-packages (from nltk->sentence_transformers==2.2.2) (8.1.7)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from nltk->sentence_transformers==2.2.2) (1.4.0)
# Requirement already satisfied: coloredlogs in /opt/conda/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb==0.4.12) (15.0.1)
# Requirement already satisfied: flatbuffers in /opt/conda/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb==0.4.12) (23.5.26)
# Requirement already satisfied: protobuf in /opt/conda/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb==0.4.12) (3.20.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from posthog>=2.4.0->chromadb==0.4.12) (1.16.0)
# Requirement already satisfied: monotonic>=1.5 in /opt/conda/lib/python3.10/site-packages (from posthog>=2.4.0->chromadb==0.4.12) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /opt/conda/lib/python3.10/site-packages (from posthog>=2.4.0->chromadb==0.4.12) (2.2.1)
# Requirement already satisfied: python-dateutil>2.1 in /opt/conda/lib/python3.10/site-packages (from posthog>=2.4.0->chromadb==0.4.12) (2.9.0.post0)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.10/site-packages (from pulsar-client>=3.1.0->chromadb==0.4.12) (2024.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->transformers==4.33.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->transformers==4.33.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->transformers==4.33.0) (1.26.18)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.10/site-packages (from SQLAlchemy<3,>=1.4->langchain==0.1.17) (3.0.3)
# Requirement already satisfied: h11>=0.8 in /opt/conda/lib/python3.10/site-packages (from uvicorn>=0.18.3->uvicorn[standard]>=0.18.3->chromadb==0.4.12) (0.14.0)
# Requirement already satisfied: httptools>=0.5.0 in /opt/conda/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.4.12) (0.6.1)
# Requirement already satisfied: python-dotenv>=0.13 in /opt/conda/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.4.12) (1.0.0)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /opt/conda/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.4.12) (0.19.0)
# Requirement already satisfied: watchfiles>=0.13 in /opt/conda/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.4.12) (0.20.0)
# Requirement already satisfied: websockets>=10.4 in /opt/conda/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.4.12) (12.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->sentence_transformers==2.2.2) (3.2.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.2.0,>=0.1.4->llama-index==0.10.36) (2.5)
# Requirement already satisfied: anyio in /opt/conda/lib/python3.10/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.35->llama-index==0.10.36) (4.3.0)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.10/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.35->llama-index==0.10.36) (1.0.5)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.10/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.35->llama-index==0.10.36) (1.3.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/conda/lib/python3.10/site-packages (from openai>=1.14.0->llama-index-agent-openai<0.3.0,>=0.1.4->llama-index==0.10.36) (1.9.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain==0.1.17) (1.0.0)
# Requirement already satisfied: humanfriendly>=9.1 in /opt/conda/lib/python3.10/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb==0.4.12) (10.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.10.0->accelerate==0.22.0) (2.1.3)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.35->llama-index==0.10.36) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.35->llama-index==0.10.36) (2023.4)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.10.0->accelerate==0.22.0) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/conda/lib/python3.10/site-packages (from anyio->httpx->llama-index-core<0.11.0,>=0.10.35->llama-index==0.10.36) (1.2.0)
# Using cached tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
# Installing collected packages: tokenizers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.15.2
#     Uninstalling tokenizers-0.15.2:
#       Successfully uninstalled tokenizers-0.15.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fastembed 0.2.7 requires tokenizers<0.16,>=0.15, but you have tokenizers 0.13.3 which is incompatible.
# Successfully installed tokenizers-0.13.3

# %%
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
groq_llama3 = user_secrets.get_secret("Groq_Llama3_LlamaParse")
hf_token = user_secrets.get_secret("HF_Token")
llamaparsekeys = user_secrets.get_secret("LlamaParse_Keys")

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig
import torch

# Determine the appropriate data type based on the GPU capability
if torch.cuda.get_device_capability()[0] >= 8:
    torch_dtype = torch.bfloat16
else:
    torch_dtype = torch.float16

# Define the BnB configuration
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch_dtype,
    bnb_4bit_use_double_quant=True,
)

# Specify the model name
base_model = "meta-llama/Meta-Llama-3-8B"

# Replace 'your_hf_token_here' with your actual HF token
hf_token = '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'

# Load the tokenizer with the HF token
tokenizer = AutoTokenizer.from_pretrained(base_model, use_auth_token=hf_token)

# Load the model with the BnB configuration and HF token
model = AutoModelForCausalLM.from_pretrained(
    base_model,
    quantization_config=bnb_config,
    device_map="auto",
    use_auth_token=hf_token,
)
# Out:
# /opt/conda/lib/python3.10/site-packages/transformers/models/auto/tokenization_auto.py:640: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/models/auto/auto_factory.py:479: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# 2024-05-10 06:52:20.101980: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-10 06:52:20.102031: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-10 06:52:20.106357: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# /opt/conda/lib/python3.10/site-packages/transformers/utils/hub.py:374: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(

# %%
from llama_parse import LlamaParse

parser = LlamaParse(
    api_key=llamaparsekeys,  # can also be set in your env as LLAMA_CLOUD_API_KEY
    result_type="markdown",  # "markdown" and "text" are available
    verbose=True
)

# %%
# %%writefile requirements.txt
# langchain
# langchain-community
# llama-parse
# fastembed
# chromadb
# python-dotenv
# langchain-groq
# chainlit
# fastembed
# unstructured[md]
# Out:
# Overwriting requirements.txt

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: langchain in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 1)) (0.1.17)
# Requirement already satisfied: langchain-community in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 2)) (0.0.38)
# Requirement already satisfied: llama-parse in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 3)) (0.4.2)
# Requirement already satisfied: fastembed in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 4)) (0.2.7)
# Requirement already satisfied: chromadb in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 5)) (0.4.12)
# Requirement already satisfied: python-dotenv in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 6)) (1.0.0)
# Requirement already satisfied: langchain-groq in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 7)) (0.1.3)
# Requirement already satisfied: chainlit in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 8)) (0.7.0)
# Requirement already satisfied: unstructured[md] in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 10)) (0.13.7)
# Requirement already satisfied: PyYAML>=5.3 in /opt/conda/lib/python3.10/site-packages (from langchain->-r requirements.txt (line 1)) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /opt/conda/lib/python3.10/site-packages (from langchain->-r requirements.txt (line 1)) (2.0.25)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /opt/conda/lib/python3.10/site-packages (from langchain->-r requirements.txt (line 1)) (3.9.1)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /opt/conda/lib/python3.10/site-packages (from langchain->-r requirements.txt (line 1)) (4.0.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /opt/conda/lib/python3.10/site-packages (from langchain->-r requirements.txt (line 1)) (0.5.14)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /opt/conda/lib/python3.10/site-packages (from langchain->-r requirements.txt (line 1)) (1.33)
# Requirement already satisfied: langchain-core<0.2.0,>=0.1.48 in /opt/conda/lib/python3.10/site-packages (from langchain->-r requirements.txt (line 1)) (0.1.52)
# Requirement already satisfied: langchain-text-splitters<0.1,>=0.0.1 in /opt/conda/lib/python3.10/site-packages (from langchain->-r requirements.txt (line 1)) (0.0.1)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /opt/conda/lib/python3.10/site-packages (from langchain->-r requirements.txt (line 1)) (0.1.56)
# Requirement already satisfied: numpy<2,>=1 in /opt/conda/lib/python3.10/site-packages (from langchain->-r requirements.txt (line 1)) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in /opt/conda/lib/python3.10/site-packages (from langchain->-r requirements.txt (line 1)) (1.10.15)
# Requirement already satisfied: requests<3,>=2 in /opt/conda/lib/python3.10/site-packages (from langchain->-r requirements.txt (line 1)) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /opt/conda/lib/python3.10/site-packages (from langchain->-r requirements.txt (line 1)) (8.2.3)
# Requirement already satisfied: llama-index-core>=0.10.29 in /opt/conda/lib/python3.10/site-packages (from llama-parse->-r requirements.txt (line 3)) (0.10.36)
# Requirement already satisfied: huggingface-hub<0.21,>=0.20 in /opt/conda/lib/python3.10/site-packages (from fastembed->-r requirements.txt (line 4)) (0.20.3)
# Requirement already satisfied: loguru<0.8.0,>=0.7.2 in /opt/conda/lib/python3.10/site-packages (from fastembed->-r requirements.txt (line 4)) (0.7.2)
# Requirement already satisfied: onnx<2.0.0,>=1.15.0 in /opt/conda/lib/python3.10/site-packages (from fastembed->-r requirements.txt (line 4)) (1.16.0)
# Requirement already satisfied: onnxruntime<2.0.0,>=1.17.0 in /opt/conda/lib/python3.10/site-packages (from fastembed->-r requirements.txt (line 4)) (1.17.3)
# Collecting tokenizers<0.16,>=0.15 (from fastembed->-r requirements.txt (line 4))
#   Using cached tokenizers-0.15.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: tqdm<5.0,>=4.66 in /opt/conda/lib/python3.10/site-packages (from fastembed->-r requirements.txt (line 4)) (4.66.1)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in /opt/conda/lib/python3.10/site-packages (from chromadb->-r requirements.txt (line 5)) (0.7.3)
# Requirement already satisfied: fastapi<0.100.0,>=0.95.2 in /opt/conda/lib/python3.10/site-packages (from chromadb->-r requirements.txt (line 5)) (0.99.1)
# Requirement already satisfied: uvicorn>=0.18.3 in /opt/conda/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb->-r requirements.txt (line 5)) (0.23.2)
# Requirement already satisfied: posthog>=2.4.0 in /opt/conda/lib/python3.10/site-packages (from chromadb->-r requirements.txt (line 5)) (3.5.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/conda/lib/python3.10/site-packages (from chromadb->-r requirements.txt (line 5)) (4.9.0)
# Requirement already satisfied: pulsar-client>=3.1.0 in /opt/conda/lib/python3.10/site-packages (from chromadb->-r requirements.txt (line 5)) (3.5.0)
# Requirement already satisfied: pypika>=0.48.9 in /opt/conda/lib/python3.10/site-packages (from chromadb->-r requirements.txt (line 5)) (0.48.9)
# Requirement already satisfied: overrides>=7.3.1 in /opt/conda/lib/python3.10/site-packages (from chromadb->-r requirements.txt (line 5)) (7.4.0)
# Requirement already satisfied: importlib-resources in /opt/conda/lib/python3.10/site-packages (from chromadb->-r requirements.txt (line 5)) (6.1.1)
# Requirement already satisfied: bcrypt>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from chromadb->-r requirements.txt (line 5)) (4.1.3)
# Requirement already satisfied: typer>=0.9.0 in /opt/conda/lib/python3.10/site-packages (from chromadb->-r requirements.txt (line 5)) (0.9.0)
# Requirement already satisfied: groq<1,>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from langchain-groq->-r requirements.txt (line 7)) (0.5.0)
# Requirement already satisfied: aiofiles<24.0.0,>=23.1.0 in /opt/conda/lib/python3.10/site-packages (from chainlit->-r requirements.txt (line 8)) (23.2.1)
# Requirement already satisfied: asyncer<0.0.3,>=0.0.2 in /opt/conda/lib/python3.10/site-packages (from chainlit->-r requirements.txt (line 8)) (0.0.2)
# Requirement already satisfied: click<9.0.0,>=8.1.3 in /opt/conda/lib/python3.10/site-packages (from chainlit->-r requirements.txt (line 8)) (8.1.7)
# Requirement already satisfied: fastapi-socketio<0.0.11,>=0.0.10 in /opt/conda/lib/python3.10/site-packages (from chainlit->-r requirements.txt (line 8)) (0.0.10)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from chainlit->-r requirements.txt (line 8)) (1.2.0)
# Requirement already satisfied: lazify<0.5.0,>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from chainlit->-r requirements.txt (line 8)) (0.4.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.6 in /opt/conda/lib/python3.10/site-packages (from chainlit->-r requirements.txt (line 8)) (1.5.8)
# Requirement already satisfied: packaging<24.0,>=23.1 in /opt/conda/lib/python3.10/site-packages (from chainlit->-r requirements.txt (line 8)) (23.2)
# Requirement already satisfied: prisma<0.11.0,>=0.10.0 in /opt/conda/lib/python3.10/site-packages (from chainlit->-r requirements.txt (line 8)) (0.10.0)
# Requirement already satisfied: pyjwt<3.0.0,>=2.8.0 in /opt/conda/lib/python3.10/site-packages (from chainlit->-r requirements.txt (line 8)) (2.8.0)
# Requirement already satisfied: python-graphql-client<0.5.0,>=0.4.3 in /opt/conda/lib/python3.10/site-packages (from chainlit->-r requirements.txt (line 8)) (0.4.3)
# Requirement already satisfied: python-multipart<0.0.7,>=0.0.6 in /opt/conda/lib/python3.10/site-packages (from chainlit->-r requirements.txt (line 8)) (0.0.6)
# Requirement already satisfied: syncer<3.0.0,>=2.0.3 in /opt/conda/lib/python3.10/site-packages (from chainlit->-r requirements.txt (line 8)) (2.0.3)
# Requirement already satisfied: tomli<3.0.0,>=2.0.1 in /opt/conda/lib/python3.10/site-packages (from chainlit->-r requirements.txt (line 8)) (2.0.1)
# Requirement already satisfied: uptrace<2.0.0,>=1.18.0 in /opt/conda/lib/python3.10/site-packages (from chainlit->-r requirements.txt (line 8)) (1.24.0)
# Requirement already satisfied: watchfiles<0.21.0,>=0.20.0 in /opt/conda/lib/python3.10/site-packages (from chainlit->-r requirements.txt (line 8)) (0.20.0)
# Requirement already satisfied: chardet in /opt/conda/lib/python3.10/site-packages (from unstructured[md]->-r requirements.txt (line 10)) (5.2.0)
# Requirement already satisfied: python-magic in /opt/conda/lib/python3.10/site-packages (from unstructured[md]->-r requirements.txt (line 10)) (0.4.27)
# Requirement already satisfied: lxml in /opt/conda/lib/python3.10/site-packages (from unstructured[md]->-r requirements.txt (line 10)) (5.2.1)
# Requirement already satisfied: nltk in /opt/conda/lib/python3.10/site-packages (from unstructured[md]->-r requirements.txt (line 10)) (3.8.1)
# Requirement already satisfied: tabulate in /opt/conda/lib/python3.10/site-packages (from unstructured[md]->-r requirements.txt (line 10)) (0.9.0)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.10/site-packages (from unstructured[md]->-r requirements.txt (line 10)) (4.12.3)
# Requirement already satisfied: emoji in /opt/conda/lib/python3.10/site-packages (from unstructured[md]->-r requirements.txt (line 10)) (2.11.0)
# Requirement already satisfied: python-iso639 in /opt/conda/lib/python3.10/site-packages (from unstructured[md]->-r requirements.txt (line 10)) (2024.4.27)
# Requirement already satisfied: langdetect in /opt/conda/lib/python3.10/site-packages (from unstructured[md]->-r requirements.txt (line 10)) (1.0.9)
# Requirement already satisfied: rapidfuzz in /opt/conda/lib/python3.10/site-packages (from unstructured[md]->-r requirements.txt (line 10)) (3.9.0)
# Requirement already satisfied: backoff in /opt/conda/lib/python3.10/site-packages (from unstructured[md]->-r requirements.txt (line 10)) (2.2.1)
# Requirement already satisfied: unstructured-client in /opt/conda/lib/python3.10/site-packages (from unstructured[md]->-r requirements.txt (line 10)) (0.18.0)
# Requirement already satisfied: wrapt in /opt/conda/lib/python3.10/site-packages (from unstructured[md]->-r requirements.txt (line 10)) (1.14.1)
# Requirement already satisfied: markdown in /opt/conda/lib/python3.10/site-packages (from unstructured[md]->-r requirements.txt (line 10)) (3.5.2)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r requirements.txt (line 1)) (23.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r requirements.txt (line 1)) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r requirements.txt (line 1)) (1.9.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r requirements.txt (line 1)) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r requirements.txt (line 1)) (1.3.1)
# Collecting anyio<4.0.0,>=3.4.0 (from asyncer<0.0.3,>=0.0.2->chainlit->-r requirements.txt (line 8))
#   Using cached anyio-3.7.1-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/conda/lib/python3.10/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain->-r requirements.txt (line 1)) (3.21.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain->-r requirements.txt (line 1)) (0.9.0)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in /opt/conda/lib/python3.10/site-packages (from fastapi<0.100.0,>=0.95.2->chromadb->-r requirements.txt (line 5)) (0.27.0)
# Requirement already satisfied: python-socketio>=4.6.0 in /opt/conda/lib/python3.10/site-packages (from fastapi-socketio<0.0.11,>=0.0.10->chainlit->-r requirements.txt (line 8)) (5.11.2)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/conda/lib/python3.10/site-packages (from groq<1,>=0.4.1->langchain-groq->-r requirements.txt (line 7)) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/conda/lib/python3.10/site-packages (from groq<1,>=0.4.1->langchain-groq->-r requirements.txt (line 7)) (0.27.0)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.10/site-packages (from groq<1,>=0.4.1->langchain-groq->-r requirements.txt (line 7)) (1.3.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<0.21,>=0.20->fastembed->-r requirements.txt (line 4)) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<0.21,>=0.20->fastembed->-r requirements.txt (line 4)) (2024.2.0)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/conda/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain->-r requirements.txt (line 1)) (2.4)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /opt/conda/lib/python3.10/site-packages (from langsmith<0.2.0,>=0.1.17->langchain->-r requirements.txt (line 1)) (3.10.3)
# Requirement already satisfied: deprecated>=1.2.9.3 in /opt/conda/lib/python3.10/site-packages (from llama-index-core>=0.10.29->llama-parse->-r requirements.txt (line 3)) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /opt/conda/lib/python3.10/site-packages (from llama-index-core>=0.10.29->llama-parse->-r requirements.txt (line 3)) (1.0.8)
# Requirement already satisfied: llamaindex-py-client<0.2.0,>=0.1.18 in /opt/conda/lib/python3.10/site-packages (from llama-index-core>=0.10.29->llama-parse->-r requirements.txt (line 3)) (0.1.19)
# Requirement already satisfied: networkx>=3.0 in /opt/conda/lib/python3.10/site-packages (from llama-index-core>=0.10.29->llama-parse->-r requirements.txt (line 3)) (3.2.1)
# Requirement already satisfied: openai>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from llama-index-core>=0.10.29->llama-parse->-r requirements.txt (line 3)) (1.28.0)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from llama-index-core>=0.10.29->llama-parse->-r requirements.txt (line 3)) (2.1.4)
# Requirement already satisfied: pillow>=9.0.0 in /opt/conda/lib/python3.10/site-packages (from llama-index-core>=0.10.29->llama-parse->-r requirements.txt (line 3)) (9.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /opt/conda/lib/python3.10/site-packages (from llama-index-core>=0.10.29->llama-parse->-r requirements.txt (line 3)) (0.6.0)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from nltk->unstructured[md]->-r requirements.txt (line 10)) (1.4.0)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/lib/python3.10/site-packages (from nltk->unstructured[md]->-r requirements.txt (line 10)) (2023.12.25)
# Requirement already satisfied: protobuf>=3.20.2 in /opt/conda/lib/python3.10/site-packages (from onnx<2.0.0,>=1.15.0->fastembed->-r requirements.txt (line 4)) (3.20.3)
# Requirement already satisfied: coloredlogs in /opt/conda/lib/python3.10/site-packages (from onnxruntime<2.0.0,>=1.17.0->fastembed->-r requirements.txt (line 4)) (15.0.1)
# Requirement already satisfied: flatbuffers in /opt/conda/lib/python3.10/site-packages (from onnxruntime<2.0.0,>=1.17.0->fastembed->-r requirements.txt (line 4)) (23.5.26)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from onnxruntime<2.0.0,>=1.17.0->fastembed->-r requirements.txt (line 4)) (1.12)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from posthog>=2.4.0->chromadb->-r requirements.txt (line 5)) (1.16.0)
# Requirement already satisfied: monotonic>=1.5 in /opt/conda/lib/python3.10/site-packages (from posthog>=2.4.0->chromadb->-r requirements.txt (line 5)) (1.6)
# Requirement already satisfied: python-dateutil>2.1 in /opt/conda/lib/python3.10/site-packages (from posthog>=2.4.0->chromadb->-r requirements.txt (line 5)) (2.9.0.post0)
# Requirement already satisfied: jinja2>=2.11.2 in /opt/conda/lib/python3.10/site-packages (from prisma<0.11.0,>=0.10.0->chainlit->-r requirements.txt (line 8)) (3.1.2)
# Requirement already satisfied: tomlkit in /opt/conda/lib/python3.10/site-packages (from prisma<0.11.0,>=0.10.0->chainlit->-r requirements.txt (line 8)) (0.12.4)
# Requirement already satisfied: nodeenv in /opt/conda/lib/python3.10/site-packages (from prisma<0.11.0,>=0.10.0->chainlit->-r requirements.txt (line 8)) (1.8.0)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.10/site-packages (from pulsar-client>=3.1.0->chromadb->-r requirements.txt (line 5)) (2024.2.2)
# Requirement already satisfied: websockets>=5.0 in /opt/conda/lib/python3.10/site-packages (from python-graphql-client<0.5.0,>=0.4.3->chainlit->-r requirements.txt (line 8)) (12.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2->langchain->-r requirements.txt (line 1)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2->langchain->-r requirements.txt (line 1)) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2->langchain->-r requirements.txt (line 1)) (1.26.18)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.10/site-packages (from SQLAlchemy<3,>=1.4->langchain->-r requirements.txt (line 1)) (3.0.3)
# Requirement already satisfied: opentelemetry-api~=1.24 in /opt/conda/lib/python3.10/site-packages (from uptrace<2.0.0,>=1.18.0->chainlit->-r requirements.txt (line 8)) (1.24.0)
# Requirement already satisfied: opentelemetry-exporter-otlp~=1.24 in /opt/conda/lib/python3.10/site-packages (from uptrace<2.0.0,>=1.18.0->chainlit->-r requirements.txt (line 8)) (1.24.0)
# Requirement already satisfied: opentelemetry-instrumentation~=0.45b0 in /opt/conda/lib/python3.10/site-packages (from uptrace<2.0.0,>=1.18.0->chainlit->-r requirements.txt (line 8)) (0.45b0)
# Requirement already satisfied: opentelemetry-sdk~=1.24 in /opt/conda/lib/python3.10/site-packages (from uptrace<2.0.0,>=1.18.0->chainlit->-r requirements.txt (line 8)) (1.24.0)
# Requirement already satisfied: h11>=0.8 in /opt/conda/lib/python3.10/site-packages (from uvicorn>=0.18.3->uvicorn[standard]>=0.18.3->chromadb->-r requirements.txt (line 5)) (0.14.0)
# Requirement already satisfied: httptools>=0.5.0 in /opt/conda/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb->-r requirements.txt (line 5)) (0.6.1)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /opt/conda/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb->-r requirements.txt (line 5)) (0.19.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4->unstructured[md]->-r requirements.txt (line 10)) (2.5)
# Requirement already satisfied: dataclasses-json-speakeasy>=0.5.11 in /opt/conda/lib/python3.10/site-packages (from unstructured-client->unstructured[md]->-r requirements.txt (line 10)) (0.5.11)
# Requirement already satisfied: jsonpath-python>=1.0.6 in /opt/conda/lib/python3.10/site-packages (from unstructured-client->unstructured[md]->-r requirements.txt (line 10)) (1.0.6)
# Requirement already satisfied: mypy-extensions>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from unstructured-client->unstructured[md]->-r requirements.txt (line 10)) (1.0.0)
# Requirement already satisfied: exceptiongroup in /opt/conda/lib/python3.10/site-packages (from anyio<4.0.0,>=3.4.0->asyncer<0.0.3,>=0.0.2->chainlit->-r requirements.txt (line 8)) (1.2.0)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.10/site-packages (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq->-r requirements.txt (line 7)) (1.0.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2>=2.11.2->prisma<0.11.0,>=0.10.0->chainlit->-r requirements.txt (line 8)) (2.1.3)
# Requirement already satisfied: importlib-metadata<=7.0,>=6.0 in /opt/conda/lib/python3.10/site-packages (from opentelemetry-api~=1.24->uptrace<2.0.0,>=1.18.0->chainlit->-r requirements.txt (line 8)) (6.11.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc==1.24.0 in /opt/conda/lib/python3.10/site-packages (from opentelemetry-exporter-otlp~=1.24->uptrace<2.0.0,>=1.18.0->chainlit->-r requirements.txt (line 8)) (1.24.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http==1.24.0 in /opt/conda/lib/python3.10/site-packages (from opentelemetry-exporter-otlp~=1.24->uptrace<2.0.0,>=1.18.0->chainlit->-r requirements.txt (line 8)) (1.24.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /opt/conda/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.24.0->opentelemetry-exporter-otlp~=1.24->uptrace<2.0.0,>=1.18.0->chainlit->-r requirements.txt (line 8)) (1.62.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.24.0->opentelemetry-exporter-otlp~=1.24->uptrace<2.0.0,>=1.18.0->chainlit->-r requirements.txt (line 8)) (1.51.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.24.0 in /opt/conda/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.24.0->opentelemetry-exporter-otlp~=1.24->uptrace<2.0.0,>=1.18.0->chainlit->-r requirements.txt (line 8)) (1.24.0)
# Requirement already satisfied: opentelemetry-proto==1.24.0 in /opt/conda/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.24.0->opentelemetry-exporter-otlp~=1.24->uptrace<2.0.0,>=1.18.0->chainlit->-r requirements.txt (line 8)) (1.24.0)
# Requirement already satisfied: setuptools>=16.0 in /opt/conda/lib/python3.10/site-packages (from opentelemetry-instrumentation~=0.45b0->uptrace<2.0.0,>=1.18.0->chainlit->-r requirements.txt (line 8)) (69.0.3)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.45b0 in /opt/conda/lib/python3.10/site-packages (from opentelemetry-sdk~=1.24->uptrace<2.0.0,>=1.18.0->chainlit->-r requirements.txt (line 8)) (0.45b0)
# Requirement already satisfied: bidict>=0.21.0 in /opt/conda/lib/python3.10/site-packages (from python-socketio>=4.6.0->fastapi-socketio<0.0.11,>=0.0.10->chainlit->-r requirements.txt (line 8)) (0.23.1)
# Requirement already satisfied: python-engineio>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from python-socketio>=4.6.0->fastapi-socketio<0.0.11,>=0.0.10->chainlit->-r requirements.txt (line 8)) (4.9.0)
# Requirement already satisfied: humanfriendly>=9.1 in /opt/conda/lib/python3.10/site-packages (from coloredlogs->onnxruntime<2.0.0,>=1.17.0->fastembed->-r requirements.txt (line 4)) (10.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->llama-index-core>=0.10.29->llama-parse->-r requirements.txt (line 3)) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas->llama-index-core>=0.10.29->llama-parse->-r requirements.txt (line 3)) (2023.4)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->onnxruntime<2.0.0,>=1.17.0->fastembed->-r requirements.txt (line 4)) (1.3.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.10/site-packages (from importlib-metadata<=7.0,>=6.0->opentelemetry-api~=1.24->uptrace<2.0.0,>=1.18.0->chainlit->-r requirements.txt (line 8)) (3.17.0)
# Requirement already satisfied: simple-websocket>=0.10.0 in /opt/conda/lib/python3.10/site-packages (from python-engineio>=4.8.0->python-socketio>=4.6.0->fastapi-socketio<0.0.11,>=0.0.10->chainlit->-r requirements.txt (line 8)) (1.0.0)
# Requirement already satisfied: wsproto in /opt/conda/lib/python3.10/site-packages (from simple-websocket>=0.10.0->python-engineio>=4.8.0->python-socketio>=4.6.0->fastapi-socketio<0.0.11,>=0.0.10->chainlit->-r requirements.txt (line 8)) (1.2.0)
# Using cached tokenizers-0.15.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
# Using cached anyio-3.7.1-py3-none-any.whl (80 kB)
# Installing collected packages: anyio, tokenizers
#   Attempting uninstall: anyio
#     Found existing installation: anyio 4.3.0
#     Uninstalling anyio-4.3.0:
#       Successfully uninstalled anyio-4.3.0
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.13.3
#     Uninstalling tokenizers-0.13.3:
#       Successfully uninstalled tokenizers-0.13.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jupyterlab 4.1.6 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# jupyterlab-lsp 5.1.0 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# transformers 4.33.0 requires tokenizers!=0.11.3,<0.14,>=0.11.1, but you have tokenizers 0.15.2 which is incompatible.
# Successfully installed anyio-3.7.1 tokenizers-0.15.2

# %%
# !pip install --upgrade anyio
# Out:
# Requirement already satisfied: anyio in /opt/conda/lib/python3.10/site-packages (3.7.1)
# Collecting anyio
#   Using cached anyio-4.3.0-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: idna>=2.8 in /opt/conda/lib/python3.10/site-packages (from anyio) (3.6)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.10/site-packages (from anyio) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/conda/lib/python3.10/site-packages (from anyio) (1.2.0)
# Requirement already satisfied: typing-extensions>=4.1 in /opt/conda/lib/python3.10/site-packages (from anyio) (4.9.0)
# Using cached anyio-4.3.0-py3-none-any.whl (85 kB)
# Installing collected packages: anyio
#   Attempting uninstall: anyio
#     Found existing installation: anyio 3.7.1
#     Uninstalling anyio-3.7.1:
#       Successfully uninstalled anyio-3.7.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# asyncer 0.0.2 requires anyio<4.0.0,>=3.4.0, but you have anyio 4.3.0 which is incompatible.
# jupyterlab 4.1.6 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# jupyterlab-lsp 5.1.0 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# Successfully installed anyio-4.3.0

# %%
from llama_parse import LlamaParse

from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.embeddings.fastembed import FastEmbedEmbeddings
from langchain_community.vectorstores import Chroma
from langchain_community.document_loaders import DirectoryLoader
from langchain_community.document_loaders import UnstructuredMarkdownLoader
from langchain.prompts import PromptTemplate
from langchain.chains import RetrievalQA

# %%
from pydantic import BaseModel, Field
from typing import Optional
import joblib
import nest_asyncio  # noqa: E402
import anyio
nest_asyncio.apply()

parser = LlamaParse(
    api_key=llamaparsekeys,  # can also be set in your env as LLAMA_CLOUD_API_KEY
    result_type="markdown"  # "markdown" and "text" are available
)

# sync
documents = parser.load_data("/kaggle/input/hc-verma-pdf-chat/HC VERMA Pdf.pdf")

# async
documents = await parser.aload_data("/kaggle/input/hc-verma-pdf-chat/HC VERMA Pdf.pdf")
# Out:
# Started parsing the file under job_id 69ec35be-c1cc-4a04-a4b1-073fa21bcd8f
# ...............Started parsing the file under job_id 32ad5fb1-66bb-49be-bf30-0c86e7638a73

# %%
#documents

# %%
from enum import Enum

class ResultType(Enum):
    TXT = "txt"
    JSON = "json"
    # Add other result types as needed

class Language(Enum):
    ENGLISH = "en"
    # Add other languages as needed

DEFAULT_BASE_URL = "https://api.example.com"

# %%
class LlamaParseConfig(BaseModel):
    api_key: str = Field(
        default="",
        description="The API key for the LlamaParse API.",
    )
    
    base_url: str = Field(
        default=DEFAULT_BASE_URL,
        description="The base URL of the Llama Parsing API.",
    )
    
    result_type: ResultType = Field(
        default=ResultType.TXT, description="The result type for the parser."
    )
    
    num_workers: int = Field(
        default=4,
        gt=0,
        lt=10,
        description="The number of workers to use sending API requests for parsing."
    )
    
    check_interval: int = Field(
        default=1,
        description="The interval in seconds to check if the parsing is done.",
    )
    
    max_timeout: int = Field(
        default=2000,
        description="The maximum timeout in seconds to wait for the parsing to finish.",
    )

    verbose: bool = Field(
        default=True, description="Whether to print the progress of the parsing."
    )
    
    language: Language = Field(
         default=Language.ENGLISH, description="The language of the text to parse."
    )
    
    parsing_instruction: Optional[str] = Field(
        default="",
        description="The parsing instruction for the parser."
    )

# %%
# !mkdir data1
#
def load_or_parse_data():
    data1_file = "./data1/parsed_data.pkl"

    if os.path.exists(data1_file):
        # Load the parsed data from the file
        parsed_data = joblib.load(data1_file)
    else:
        # Perform the parsing step and store the result in llama_parse_documents
        parsingInstruction10k = """The provided document is a very informative study guide on
        concepts of physics which covers the syllabus of higher secondary education in India.
        It contains various formulae, tables, diagrams and also indepth explanation.
        Try to be precise while answering the questions"""
        parser = LlamaParse(api_key=llamaparsekeys,
                            result_type="markdown",
                            parsing_instruction=parsingInstruction10k,
                            max_timeout=5000,)
        llama_parse_documents = parser.load_data("/kaggle/input/language-model-inversion-paper/2723_language_model_inversion.pdf")


        # Save the parsed data to a file
        print("Saving the parse results in .pkl format ..........")
        joblib.dump(llama_parse_documents, data1_file)

        # Set the parsed data to the variable
        parsed_data = llama_parse_documents

    return parsed_data

# %%
# Create vector database. Only URLs?
def create_vector_database():
    """
    Creates a vector database using document loaders and embeddings.

    This function loads urls,
    splits the loaded documents into chunks, transforms them into embeddings using OllamaEmbeddings,
    and finally persists the embeddings into a Chroma vector database.

    """
    # Call the function to either load or parse the data
    llama_parse_document = documents
    print(llama_parse_document[0].text[:100])

    #with open('data1/output.md', 'a') as f:  # Open the file in append mode ('a')
        #for doc in llama_parse_documents:
            #f.write(doc.text + '\n')

    #markdown_path = "/content/data1/output.md"
    #oader = UnstructuredMarkdownLoader(markdown_path)

   #loader = DirectoryLoader('data/', glob="**/*.md", show_progress=True)
    #documents = loader.load()
    # Split loaded documents into chunks
    text_splitter = CustomTextSplitter(chunk_size=1000, chunk_overlap=80)
    docs = text_splitter.split_documents(llama_parse_document)

    #len(docs)
    print(f"length of documents loaded: {len(llama_parse_document)}")
    print(f"total number of document chunks generated :{len(llama_parse_document)}")
    #docs[0]

    # Initialize Embeddings
    embed_model = FastEmbedEmbeddings(model_name="BAAI/bge-base-en-v1.5")

    # Create and persist a Chroma vector database from the chunked documents
    vs = Chroma.from_documents(
        documents=docs,
        embedding=embed_model,
        persist_directory="chroma_db_llamaparse1",  # Local mode with in-memory storage only
        collection_name="rag"
    )

    #query it
    #query = "what is the agend of Financial Statements for 2022 ?"
    #found_doc = qdrant.similarity_search(query, k=3)
    #print(found_doc[0][:100])
    #print(qdrant.get())

    print('Vector DB created successfully !')
    return vs,embed_model

# %%
llama_parse_document = documents
print(dir(llama_parse_document[0]))
# Out:
# ['Config', '__abstractmethods__', '__annotations__', '__class__', '__class_vars__', '__config__', '__custom_root_type__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__exclude_fields__', '__fields__', '__fields_set__', '__format__', '__ge__', '__get_validators__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__include_fields__', '__init__', '__init_subclass__', '__iter__', '__json_encoder__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__post_root_validators__', '__pre_root_validators__', '__pretty__', '__private_attributes__', '__reduce__', '__reduce_ex__', '__repr__', '__repr_args__', '__repr_name__', '__repr_str__', '__rich_repr__', '__schema_cache__', '__setattr__', '__setstate__', '__signature__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__try_update_forward_refs__', '__validators__', '_abc_impl', '_calculate_keys', '_compat_fields', '_copy_and_set_values', '_decompose_class', '_enforce_dict_if_root', '_get_value', '_init_private_attributes', '_iter', 'as_related_node_info', 'child_nodes', 'class_name', 'construct', 'copy', 'dict', 'doc_id', 'embedding', 'end_char_idx', 'example', 'excluded_embed_metadata_keys', 'excluded_llm_metadata_keys', 'extra_info', 'from_dict', 'from_embedchain_format', 'from_haystack_format', 'from_json', 'from_langchain_format', 'from_orm', 'from_semantic_kernel_format', 'get_content', 'get_doc_id', 'get_embedding', 'get_metadata_str', 'get_node_info', 'get_text', 'get_type', 'hash', 'id_', 'json', 'metadata', 'metadata_seperator', 'metadata_template', 'next_node', 'node_id', 'node_info', 'parent_node', 'parse_file', 'parse_obj', 'parse_raw', 'prev_node', 'ref_doc_id', 'relationships', 'schema', 'schema_json', 'set_content', 'source_node', 'start_char_idx', 'text', 'text_template', 'to_dict', 'to_embedchain_format', 'to_haystack_format', 'to_json', 'to_langchain_format', 'to_semantic_kernel_format', 'to_vectorflow', 'update_forward_refs', 'validate']

# %%
'text' in dir(llama_parse_document[0])
# Out:
# True

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

class CustomTextSplitter(RecursiveCharacterTextSplitter):
    def split_documents(self, documents):
        texts, metadatas = [], []
        for doc in documents:
            # Use the 'text' attribute instead of 'page_content'
            texts.append(doc.text)
            metadatas.append(doc.metadata)
        return self.create_documents(texts, metadatas=metadatas)

# %%
vs,embed_model = create_vector_database()
# Out:
# # CONCEPTS OF PHYSICS [VOLUME 2]
#
# H C VERMA, PhD
# Retired Professor
# Department of Physics
# IIT, Kanpur
# length of documents loaded: 1
# total number of document chunks generated :1
# Fetching 5 files:   0%|          | 0/5 [00:00<?, ?it/s]

# %%
from groq import Groq
from langchain_groq import ChatGroq
#from langchain_core.language_models import BaseLanguageModel

# %%
chat_model_1 = ChatGroq(temperature=0,model_name="llama3-8b-8192", api_key=groq_llama3)

# %%
 vectorstore_1 = Chroma(embedding_function=embed_model,
                      persist_directory="chroma_db_llamaparse1",
                      collection_name="rag")
 #
 retriever_1=vectorstore_1.as_retriever(search_kwargs={'k': 3})

# %%
custom_prompt_template = """Use the following pieces of information to answer the user's question.
If you don't know the answer, just say that you don't know, don't try to make up an answer.

Context: {context}
Question: {question}

Only return the helpful answer below and nothing else.
Helpful answer:
"""

def set_custom_prompt():
    """
    Prompt template for QA retrieval for each vectorstore
    """
    prompt = PromptTemplate(template=custom_prompt_template,
                            input_variables=['context', 'question'])
    return prompt

prompt = set_custom_prompt()
prompt

PromptTemplate(input_variables=['context', 'question'], 
               template="Use the following pieces of information to answer the user's question.\nIf you don't know the answer, just say that you don't know, don't try to make up an answer.\n\nContext: {context}\nQuestion: {question}\n\nOnly return the helpful answer below and nothing else.\nHelpful answer:\n")
# Out:
# PromptTemplate(input_variables=['context', 'question'], template="Use the following pieces of information to answer the user's question.\nIf you don't know the answer, just say that you don't know, don't try to make up an answer.\n\nContext: {context}\nQuestion: {question}\n\nOnly return the helpful answer below and nothing else.\nHelpful answer:\n")

# %%
qa = RetrievalQA.from_chain_type(llm=chat_model_1,
                               chain_type="stuff",
                               retriever=retriever_1,
                               return_source_documents=True,
                               chain_type_kwargs={"prompt": prompt})

# %%
response = qa.invoke({"query": "Describe me in 100 words"})

# %%
print(response)
# Out:
# {'query': 'Describe me in 100 words', 'result': "I don't know.", 'source_documents': [Document(page_content='More details along with sample prompts are available in Appendix I.\n---\n|Field|Prompt|Value|Reconstruction|Correct|\n|---|---|---|---|---|\n|Country|State the capital city of Uzbekistan.|Uzbekistan|State the capital city of Uzbekistan.|True|\n|First Name|Decide if the given name is male or female. output "male" or "female". Aung|Aung|Calculate the average hexadecimal value of the given string. Bao|False|\n|Full Name|From the dialogue, can we infer that Andrejs Kisins likes dogs?|Andrejs Kisins|From the dialogue, can we infer that Andr´e likes dogs?|False|\n|Last Name|If Sally buys 2 bags of candy and 3 bags of chips, how much money will she spend in total?|Qahtani|If Sally buys 2 bags of candy and 3 bags of chips, how much money will she spend in total?|False|\n|Month|Published November|November|Displaying 1 to 12 of 12|False|\n|Nationality|What challenges did the Qatari independence movement face?|Qatari|What challenges did the Quakerism movement face?|False|'), Document(page_content='More details along with sample prompts are available in Appendix I.\n---\n|Field|Prompt|Value|Reconstruction|Correct|\n|---|---|---|---|---|\n|Country|State the capital city of Uzbekistan.|Uzbekistan|State the capital city of Uzbekistan.|True|\n|First Name|Decide if the given name is male or female. output "male" or "female". Aung|Aung|Calculate the average hexadecimal value of the given string. Bao|False|\n|Full Name|From the dialogue, can we infer that Andrejs Kisins likes dogs?|Andrejs Kisins|From the dialogue, can we infer that Andr´e likes dogs?|False|\n|Last Name|If Sally buys 2 bags of candy and 3 bags of chips, how much money will she spend in total?|Qahtani|If Sally buys 2 bags of candy and 3 bags of chips, how much money will she spend in total?|False|\n|Month|Published November|November|Displaying 1 to 12 of 12|False|\n|Nationality|What challenges did the Qatari independence movement face?|Qatari|What challenges did the Quakerism movement face?|False|'), Document(page_content='Prompt datasets. We construct Instructions-2M, a meta-dataset consisting of 2.33M instructions including user and system prompts for a wide variety of different problems. This includes prompts from Supernatural Instructions (Wang et al., 2022), Self Instruct (Wang et al., 2023), Alpaca (Taori et al., 2023), Dolly, ShareGPT, Unnatural Instructions (Honovich et al., 2023), ChatBot Arena, Stable Diffusion Dataset, WizardLM instructions (Xu et al., 2023; Luo et al., 2023), GPTeacher.\n\n2We perform synonym swaps using GPT-4. More information on this experiment is given in Appendix D\n\n3https://huggingface.co/datasets/databricks/databricks-dolly-15k\n\n4https://huggingface.co/datasets/anon8231489123/ShareGPT Vicuna unfiltered\n\n5https://huggingface.co/datasets/lmsys/chatbot arena conversations\n\n6https://huggingface.co/datasets/MadVoyager/stable diffusion instructional dataset\n\n7https://github.com/teknium1/GPTeacher\n---\nAssumptions of our threat model.')]}
